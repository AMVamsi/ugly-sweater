# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
import pandas as pd
import random
import os
import openai

openai.api_key = "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"
openai.Model.list()

inputPersonalityType = "INFP"

df = pd.read_csv("/content/drive/Shareddrives/UglySweater/PersonalityColorHex.csv") #Reading File Data
listPersonalities = []
for i in df['Personality']: #Creating a list for personality-type headers
    listPersonalities.append(i)


def dallEimg(text): #Dall-E api to get image for sweater template
    openai.Image.create(
        prompt = text,
        n = 2,
        size = "1024x1024"
    )
    pass
def dallEimg(text):
    pass



def personalityText(input): #Using this function to get text.
    text = ""
    index = listPersonalities.index(input)
    result = df.loc[index]
    listSen = []
    for i in result:
        listSen.append(i)
    # text = "Colors in pattern " + listSen[1] +", "+ listSen[3]+" and " + listSen[5] + " with "+listSen[7] + ", " +listSen[8]+" and "+ listSen[9] + " with " + listSen[10] + "."
    # return text
    text = "Colors in pattern "  + listSen[random.choice([1,3,5])] + " with " + listSen[7] + " and " +listSen[random.randint(8,9)] + " with " + listSen[10] + "."
    return text


a = personalityText(inputPersonalityType)
print(a)
newIMG = dallEimg(personalityText(inputPersonalityType))
print(newIMG)
# Out:
# Colors in pattern Pale Pink with Fantasy-inspired art and Bright colors with Christmas Theme.
# None

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import requests

url = "https://api.newnative.ai/stable-diffusion?prompt=futuristic spce station, 4k digital art"

response = requests.request("GET", url)
print(response)
data = response.json()
print(data["image_url"])
# Out:
# <Response [524]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-13-cb2289e9739f> in <module>
#       5 response = requests.request("GET", url)
#       6 print(response)
# ----> 7 data = response.json()
#       8 print(data["image_url"])
#
# /usr/local/lib/python3.8/dist-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# /usr/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
# ...

# %%
# !pip install openai

# %%
"""
use the image generated and pass it through 
https://kosamari.github.io/sweaterify/ also make sure to replace the
place holder of INFP with the actual personality inputted
"""
